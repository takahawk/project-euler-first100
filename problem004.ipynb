# %% [markdown]
# # Largest palindrome product
# ## Problem 4
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
numbers = range(100, 1000)

# %%
def is_palindrome(n):
    return str(n) == str(n)[::-1]

assert(is_palindrome(9009))
assert(not is_palindrome(9099))

# %%
products = sorted([x * y for x in numbers for y in numbers], reverse=True)
products
# Out:
# [998001,
#  997002,
#  997002,
#  996004,
#  996003,
#  996003,
#  995006,
#  995006,
#  995004,
#  995004,
#  994009,
#  994008,
#  994008,
#  994005,
#  994005,
#  993012,
#  993012,
#  993010,
#  993010,
#  993006,
#  993006,
#  992016,
#  992015,
#  992015,
#  992012,
#  992012,
#  992007,
#  992007,
#  991020,
#  991020,
#  991018,
#  991018,
#  991014,
#  991014,
#  991008,
#  991008,
#  990025,
#  990024,
#  990024,
#  990021,
#  990021,
#  990016,
#  990016,
#  990009,
#  990009,
#  989030,
#  989030,
#  989028,
#  989028,
#  989024,
#  989024,
#  989018,
#  989018,
#  989010,
#  989010,
#  988036,
#  988035,
#  988035,
#  988032,
#  988032,
#  988027,
#  988027,
#  988020,
#  988020,
#  988011,
#  988011,
#  987042,
#  987042,
#  987040,
#  987040,
#  987036,
#  987036,
#  987030,
#  987030,
#  987022,
#  987022,
#  987012,
#  987012,
#  986049,
#  986048,
#  986048,
#  986045,
#  986045,
#  986040,
#  986040,
#  986033,
#  986033,
#  986024,
#  986024,
#  986013,
#  986013,
#  985056,
#  985056,
#  985054,
#  985054,
#  985050,
#  985050,
#  985044,
#  985044,
#  985036,
#  985036,
#  985026,
#  985026,
#  985014,
#  985014,
#  984064,
#  984063,
#  984063,
#  984060,
#  984060,
#  984055,
#  984055,
#  984048,
#  984048,
#  984039,
#  984039,
#  984028,
#  984028,
#  984015,
#  984015,
#  983072,
#  983072,
#  983070,
#  983070,
#  983066,
#  983066,
#  983060,
#  983060,
#  983052,
#  983052,
#  983042,
#  983042,
#  983030,
#  983030,
#  983016,
#  983016,
#  982081,
#  982080,
#  982080,
#  982077,
#  982077,
#  982072,
#  982072,
#  982065,
#  982065,
#  982056,
#  982056,
#  982045,
#  982045,
#  982032,
#  982032,
#  982017,
#  982017,
#  981090,
#  981090,
#  981088,
#  981088,
#  981084,
#  981084,
#  981078,
#  981078,
#  981070,
#  981070,
#  981060,
#  981060,
#  981048,
#  981048,
#  981034,
#  981034,
#  981018,
#  981018,
#  980100,
#  980099,
#  980099,
#  980096,
#  980096,
#  980091,
#  980091,
#  980084,
#  980084,
#  980075,
#  980075,
#  980064,
#  980064,
#  980051,
#  980051,
#  980036,
#  980036,
#  980019,
#  980019,
#  979110,
#  979110,
#  979108,
#  979108,
#  979104,
#  979104,
#  979098,
#  979098,
#  979090,
#  979090,
#  979080,
#  979080,
#  979068,
#  979068,
#  979054,
#  979054,
#  979038,
#  979038,
#  979020,
#  979020,
#  978121,
#  978120,
#  978120,
#  978117,
#  978117,
#  978112,
#  978112,
#  978105,
#  978105,
#  978096,
#  978096,
#  978085,
#  978085,
#  978072,
#  978072,
#  978057,
#  978057,
#  978040,
#  978040,
#  978021,
#  978021,
#  977132,
#  977132,
#  977130,
#  977130,
#  977126,
#  977126,
#  977120,
#  977120,
#  977112,
#  977112,
#  977102,
#  977102,
#  977090,
#  977090,
#  977076,
#  977076,
#  977060,
#  977060,
#  977042,
#  977042,
#  977022,
#  977022,
#  976144,
#  976143,
#  976143,
#  976140,
#  976140,
#  976135,
#  976135,
#  976128,
#  976128,
#  976119,
#  976119,
#  976108,
#  976108,
#  976095,
#  976095,
#  976080,
#  976080,
#  976063,
#  976063,
#  976044,
#  976044,
#  976023,
#  976023,
#  975156,
#  975156,
#  975154,
#  975154,
#  975150,
#  975150,
#  975144,
#  975144,
#  975136,
#  975136,
#  975126,
#  975126,
#  975114,
#  975114,
#  975100,
#  975100,
#  975084,
#  975084,
#  975066,
#  975066,
#  975046,
#  975046,
#  975024,
#  975024,
#  974169,
#  974168,
#  974168,
#  974165,
#  974165,
#  974160,
#  974160,
#  974153,
#  974153,
#  974144,
#  974144,
#  974133,
#  974133,
#  974120,
#  974120,
#  974105,
#  974105,
#  974088,
#  974088,
#  974069,
#  974069,
#  974048,
#  974048,
#  974025,
#  974025,
#  973182,
#  973182,
#  973180,
#  973180,
#  973176,
#  973176,
#  973170,
#  973170,
#  973162,
#  973162,
#  973152,
#  973152,
#  973140,
#  973140,
#  973126,
#  973126,
#  973110,
#  973110,
#  973092,
#  973092,
#  973072,
#  973072,
#  973050,
#  973050,
#  973026,
#  973026,
#  972196,
#  972195,
#  972195,
#  972192,
#  972192,
#  972187,
#  972187,
#  972180,
#  972180,
#  972171,
#  972171,
#  972160,
#  972160,
#  972147,
#  972147,
#  972132,
#  972132,
#  972115,
#  972115,
#  972096,
#  972096,
#  972075,
#  972075,
#  972052,
#  972052,
#  972027,
#  972027,
#  971210,
#  971210,
#  971208,
#  971208,
#  971204,
#  971204,
#  971198,
#  971198,
#  971190,
#  971190,
#  971180,
#  971180,
#  971168,
#  971168,
#  971154,
#  971154,
#  971138,
#  971138,
#  971120,
#  971120,
#  971100,
#  971100,
#  971078,
#  971078,
#  971054,
#  971054,
#  971028,
#  971028,
#  970225,
#  970224,
#  970224,
#  970221,
#  970221,
#  970216,
#  970216,
#  970209,
#  970209,
#  970200,
#  970200,
#  970189,
#  970189,
#  970176,
#  970176,
#  970161,
#  970161,
#  970144,
#  970144,
#  970125,
#  970125,
#  970104,
#  970104,
#  970081,
#  970081,
#  970056,
#  970056,
#  970029,
#  970029,
#  969240,
#  969240,
#  969238,
#  969238,
#  969234,
#  969234,
#  969228,
#  969228,
#  969220,
#  969220,
#  969210,
#  969210,
#  969198,
#  969198,
#  969184,
#  969184,
#  969168,
#  969168,
#  969150,
#  969150,
#  969130,
#  969130,
#  969108,
#  969108,
#  969084,
#  969084,
#  969058,
#  969058,
#  969030,
#  969030,
#  968256,
#  968255,
#  968255,
#  968252,
#  968252,
#  968247,
#  968247,
#  968240,
#  968240,
#  968231,
#  968231,
#  968220,
#  968220,
#  968207,
#  968207,
#  968192,
#  968192,
#  968175,
#  968175,
#  968156,
#  968156,
#  968135,
#  968135,
#  968112,
#  968112,
#  968087,
#  968087,
#  968060,
#  968060,
#  968031,
#  968031,
#  967272,
#  967272,
#  967270,
#  967270,
#  967266,
#  967266,
#  967260,
#  967260,
#  967252,
#  967252,
#  967242,
#  967242,
#  967230,
#  967230,
#  967216,
#  967216,
#  967200,
#  967200,
#  967182,
#  967182,
#  967162,
#  967162,
#  967140,
#  967140,
#  967116,
#  967116,
#  967090,
#  967090,
#  967062,
#  967062,
#  967032,
#  967032,
#  966289,
#  966288,
#  966288,
#  966285,
#  966285,
#  966280,
#  966280,
#  966273,
#  966273,
#  966264,
#  966264,
#  966253,
#  966253,
#  966240,
#  966240,
#  966225,
#  966225,
#  966208,
#  966208,
#  966189,
#  966189,
#  966168,
#  966168,
#  966145,
#  966145,
#  966120,
#  966120,
#  966093,
#  966093,
#  966064,
#  966064,
#  966033,
#  966033,
#  965306,
#  965306,
#  965304,
#  965304,
#  965300,
#  965300,
#  965294,
#  965294,
#  965286,
#  965286,
#  965276,
#  965276,
#  965264,
#  965264,
#  965250,
#  965250,
#  965234,
#  965234,
#  965216,
#  965216,
#  965196,
#  965196,
#  965174,
#  965174,
#  965150,
#  965150,
#  965124,
#  965124,
#  965096,
#  965096,
#  965066,
#  965066,
#  965034,
#  965034,
#  964324,
#  964323,
#  964323,
#  964320,
#  964320,
#  964315,
#  964315,
#  964308,
#  964308,
#  964299,
#  964299,
#  964288,
#  964288,
#  964275,
#  964275,
#  964260,
#  964260,
#  964243,
#  964243,
#  964224,
#  964224,
#  964203,
#  964203,
#  964180,
#  964180,
#  964155,
#  964155,
#  964128,
#  964128,
#  964099,
#  964099,
#  964068,
#  964068,
#  964035,
#  964035,
#  963342,
#  963342,
#  963340,
#  963340,
#  963336,
#  963336,
#  963330,
#  963330,
#  963322,
#  963322,
#  963312,
#  963312,
#  963300,
#  963300,
#  963286,
#  963286,
#  963270,
#  963270,
#  963252,
#  963252,
#  963232,
#  963232,
#  963210,
#  963210,
#  963186,
#  963186,
#  963160,
#  963160,
#  963132,
#  963132,
#  963102,
#  963102,
#  963070,
#  963070,
#  963036,
#  963036,
#  962361,
#  962360,
#  962360,
#  962357,
#  962357,
#  962352,
#  962352,
#  962345,
#  962345,
#  962336,
#  962336,
#  962325,
#  962325,
#  962312,
#  962312,
#  962297,
#  962297,
#  962280,
#  962280,
#  962261,
#  962261,
#  962240,
#  962240,
#  962217,
#  962217,
#  962192,
#  962192,
#  962165,
#  962165,
#  962136,
#  962136,
#  962105,
#  962105,
#  962072,
#  962072,
#  962037,
#  962037,
#  961380,
#  961380,
#  961378,
#  961378,
#  961374,
#  961374,
#  961368,
#  961368,
#  961360,
#  961360,
#  961350,
#  961350,
#  961338,
#  961338,
#  961324,
#  961324,
#  961308,
#  961308,
#  961290,
#  961290,
#  961270,
#  961270,
#  961248,
#  961248,
#  961224,
#  961224,
#  961198,
#  961198,
#  961170,
#  961170,
#  961140,
#  961140,
#  961108,
#  961108,
#  961074,
#  961074,
#  961038,
#  961038,
#  960400,
#  960399,
#  960399,
#  960396,
#  960396,
#  960391,
#  960391,
#  960384,
#  960384,
#  960375,
#  960375,
#  960364,
#  960364,
#  960351,
#  960351,
#  960336,
#  960336,
#  960319,
#  960319,
#  960300,
#  960300,
#  960279,
#  960279,
#  960256,
#  960256,
#  960231,
#  960231,
#  960204,
#  960204,
#  960175,
#  960175,
#  960144,
#  960144,
#  960111,
#  960111,
#  960076,
#  960076,
#  960039,
#  960039,
#  959420,
#  959420,
#  959418,
#  959418,
#  959414,
#  959414,
#  959408,
#  959408,
#  959400,
#  959400,
#  959390,
#  959390,
#  959378,
#  959378,
#  959364,
#  959364,
#  959348,
#  959348,
#  959330,
#  959330,
#  959310,
#  959310,
#  959288,
#  959288,
#  959264,
#  959264,
#  959238,
#  959238,
#  959210,
#  959210,
#  959180,
#  959180,
#  959148,
#  959148,
#  959114,
#  959114,
#  959078,
#  959078,
#  959040,
#  959040,
#  958441,
#  958440,
#  958440,
#  958437,
#  958437,
#  958432,
#  958432,
#  958425,
#  958425,
#  958416,
#  958416,
#  958405,
#  958405,
#  958392,
#  958392,
#  958377,
#  958377,
#  958360,
#  958360,
#  958341,
#  958341,
#  958320,
#  958320,
#  958297,
#  958297,
#  958272,
#  958272,
#  958245,
#  958245,
#  958216,
#  958216,
#  958185,
#  958185,
#  958152,
#  958152,
#  958117,
#  958117,
#  958080,
#  958080,
#  958041,
#  958041,
#  957462,
#  957462,
#  957460,
#  957460,
#  957456,
#  957456,
#  957450,
#  957450,
#  957442,
#  957442,
#  957432,
#  957432,
#  957420,
#  957420,
#  957406,
#  957406,
#  957390,
#  957390,
#  957372,
#  957372,
#  957352,
#  957352,
#  957330,
#  957330,
#  957306,
#  957306,
#  957280,
#  957280,
#  957252,
#  957252,
#  957222,
#  957222,
#  957190,
#  957190,
#  957156,
#  957156,
#  957120,
#  957120,
#  957082,
#  957082,
#  957042,
#  957042,
#  956484,
#  956483,
#  956483,
#  956480,
#  956480,
#  956475,
#  956475,
#  956468,
#  956468,
#  956459,
#  956459,
#  956448,
#  956448,
#  956435,
#  956435,
#  956420,
#  956420,
#  956403,
#  956403,
#  956384,
#  956384,
#  956363,
#  956363,
#  956340,
#  956340,
#  956315,
#  956315,
#  956288,
#  956288,
#  956259,
#  956259,
#  956228,
#  956228,
#  956195,
#  956195,
#  956160,
#  956160,
#  956123,
#  956123,
#  956084,
#  956084,
#  956043,
#  956043,
#  955506,
#  955506,
#  955504,
#  955504,
#  955500,
#  955500,
#  955494,
#  955494,
#  955486,
#  955486,
#  955476,
#  955476,
#  955464,
#  955464,
#  955450,
#  955450,
#  955434,
#  955434,
#  955416,
#  955416,
#  955396,
#  955396,
#  955374,
#  955374,
#  955350,
#  955350,
#  955324,
#  955324,
#  955296,
#  955296,
#  955266,
#  955266,
#  955234,
#  955234,
#  955200,
#  955200,
#  955164,
#  955164,
#  955126,
#  955126,
#  955086,
#  955086,
#  955044,
#  955044,
#  954529,
#  954528,
#  954528,
#  954525,
#  954525,
#  954520,
#  954520,
#  954513,
#  954513,
#  954504,
#  ...]

# %%
answer = [x for x in products if is_palindrome(x)][0]
print("Answer is ", answer)
# Out:
# Answer is  906609
