# %% [markdown]
# # Highly divisible triangular number
# ## Problem 12
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7<sup>th</sup> triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
# <center>1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...</center>
#
# Let us list the factors of the first seven triangle numbers:
#
# <b>1</b>: 1
# <b>3</b>: 1,3
# <b>6</b>: 1,2,3,6
# <b>10</b>: 1,2,5,10
# <b>15</b>: 1,3,5,15
# <b>21</b>: 1,3,7,21
# <b>28</b>: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
def get_first_triangle_number(predicate):
    a = 0
    i = 1
    while True:
        a += i
        i += 1
        if predicate(a):
            return a

get_first_triangle_number(lambda x: x > 100)
# Out:
# 105

# %%
def get_divisors_number(n):
    factors = dict()
    d = 2
    while n >= d:
        if n % d == 0:
            n /= d
            factors[d] = factors.setdefault(d, 0) + 1
        else:
            d += 1

    res = 1
    for v in factors.values():
        # find combinations of prime divisors (including prime factors in power 0)
        res *= (v + 1)

    return res

get_divisors_number(28)
# Out:
# 6

# %%
answer = get_first_triangle_number(lambda x: get_divisors_number(x) > 500)
print("Answer is ", answer)
# Out:
# Answer is  76576500
